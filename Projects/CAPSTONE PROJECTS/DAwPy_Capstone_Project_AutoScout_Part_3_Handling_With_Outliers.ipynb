# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy import stats
from scipy.stats.mstats import winsorize

import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 150

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %%
df = pd.read_csv("cleaned_scout.csv")

# %%
data = df.copy

# %%
df.shape
# Out:
# (15909, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15909 entries, 0 to 15908
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15909 non-null  object
#  1   body_type            15909 non-null  object
#  2   price                15909 non-null  int64
#  3   vat                  15909 non-null  object
#  4   km                   15909 non-null  float64
#  5   Type                 15909 non-null  object
#  6   Fuel                 15909 non-null  object
#  7   Gears                15909 non-null  float64
#  8   Extras               15909 non-null  object
#  9   Previous_Owners      15909 non-null  float64
#  10  hp_kW                15909 non-null  float64
#  11  Age                  15909 non-null  float64
#  12  Paint_Type           15909 non-null  object
#  13  Upholstery_type      15909 non-null  object
#  14  Nr_of_Doors          15909 non-null  float64
#  15  Nr_of_Seats          15909 non-null  float64
#  16  Gearing_Type         15909 non-null  object
#  17  Displacement_cc      15909 non-null  float64
#  18  Weight_kg            15909 non-null  float64
#  19  Drive_chain          15909 non-null  object
#  20  Consumption_comb     15909 non-null  float64
#  21  CO2_Emission         15909 non-null  float64
#  22  Emission_Class       15909 non-null  object
#  23  Comfort_Convenience  15909 non-null  object
#  24  Entertainment_Media  15909 non-null  object
#  25  Safety_Security      15909 non-null  object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 3.2+ MB

# %%
df.describe(exclude= "object").T
# Out:
#                      count      mean       std    min       25%       50%  \
# price            15909.000 18019.186  7384.579 13.000 12850.000 16900.000
# km               15909.000 32084.265 36986.803  0.000  2493.427 20407.000
# Gears            15909.000     5.938     0.705  5.000     5.000     6.000
# Previous_Owners  15909.000     1.040     0.254  0.000     1.000     1.000
# hp_kW            15909.000    88.371    26.834  1.000    66.000    85.000
# Age              15909.000     1.390     1.121  0.000     0.000     1.000
# Nr_of_Doors      15909.000     4.655     0.647  1.000     4.000     5.000
# Nr_of_Seats      15909.000     4.952     0.500  2.000     5.000     5.000
# Displacement_cc  15909.000  1425.547   329.775  1.000  1229.000  1461.000
# Weight_kg        15909.000  1337.437   200.437  1.000  1165.000  1295.000
# Consumption_comb 15909.000     4.900     1.537  0.000     4.200     4.800
# CO2_Emission     15909.000   110.665    33.852  0.000   104.000   116.000
#
#                        75%        max
# price            21900.000  74600.000
# km               46928.000 317000.000
# Gears                6.000      8.000
# Previous_Owners      1.000      4.000
# hp_kW              101.000    294.000
# Age                  2.000      3.000
# Nr_of_Doors          5.000      7.000
# Nr_of_Seats          5.000      7.000
# Displacement_cc   1598.000  16000.000
# Weight_kg         1472.000   2471.000
# Consumption_comb     5.484     55.000
# CO2_Emission       128.000    990.000

# %%
# Calculating of limits
def limits(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3-Q1
    lower_lim= Q1-1.5*IQR
    upper_lim= Q3+1.5*IQR
    
    print("Lower Limit:",lower_lim) 
    print("Upper limit:", upper_lim)

# %%
# Counting of Outliers
def outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3-Q1
    lower_lim= Q1-1.5*IQR
    upper_lim= Q3+1.5*IQR
    
    return ((df[column]<lower_lim) | (df[column]>upper_lim)).sum()

# %%
# Dropping of Outliers
def dropping_of_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3-Q1
    lower_lim= Q1-1.5*IQR
    upper_lim= Q3+1.5*IQR
    
    return df[column].loc[~((df[column]<lower_lim) | (df[column]>upper_lim))]

# %%
#Explore different quantiles at the upper end
def winsorize_percentage_selection(df,column):
    print('90% quantile:   ', df[column].quantile(0.90))      
    print('92.5% quantile: ', df[column].quantile(0.925))      
    print('95% quantile:   ', df[column].quantile(0.95))       
    print('97.5% quantile: ', df[column].quantile(0.975))      
    print('99% quantile:   ', df[column].quantile(0.99))       
    print('99.9% quantile: ', df[column].quantile(0.999))

# %% [markdown]
# ## price

# %%
df.price.count()
# Out:
# 15909

# %%
df.price.describe()
# Out:
# count   15909.000
# mean    18019.186
# std      7384.579
# min        13.000
# 25%     12850.000
# 50%     16900.000
# 75%     21900.000
# max     74600.000
# Name: price, dtype: float64

# %%
df.price.sort_values(ascending=True).head(10)
# Out:
# 8592       13
# 8826      120
# 6064      255
# 8827      331
# 8825     4950
# 8823     4990
# 8824     5250
# 8822     5300
# 13764    5445
# 8821     5450
# Name: price, dtype: int64

# %%
limits(df,"price")
# Out:
# Lower Limit: -725.0
# Upper limit: 35475.0

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.price)

plt.subplot(122)
plt.hist(df.price,bins=20);

# %%
outliers(df,"price")
# Out:
# 479

# %%
winsorize_percentage_selection(df,"price")
# Out:
# 90% quantile:    26980.0
# 92.5% quantile:  28820.0
# 95% quantile:    31990.0
# 97.5% quantile:  36493.09999999999
# 99% quantile:    40413.60000000003
# 99.9% quantile:  56904.60000000012

# %% [markdown]
# %97.5 Quantile has selected.

# %%
df.price= winsorize(df["price"],(0, 0.025),inplace=True)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.price)

plt.subplot(122)
plt.hist(df.price,bins=20);

# %%
df.price.describe()
# Out:
# count   15909.000
# mean    17877.245
# std      6887.950
# min        13.000
# 25%     12850.000
# 50%     16900.000
# 75%     21900.000
# max     36498.000
# Name: price, dtype: float64

# %% [markdown]
# ## km

# %%
df.km.describe()
# Out:
# count    15909.000
# mean     32084.265
# std      36986.803
# min          0.000
# 25%       2493.427
# 50%      20407.000
# 75%      46928.000
# max     317000.000
# Name: km, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.km)

plt.subplot(122)
plt.hist(df.km,bins=20);

# %%
limits(df,"km")
# Out:
# Lower Limit: -64158.43196202531
# Upper limit: 113579.85917721518

# %%
outliers(df,"km")
# Out:
# 700

# %%
winsorize_percentage_selection(df,"km")
# Out:
# 90% quantile:    87999.0
# 92.5% quantile:  97000.0
# 95% quantile:    109959.99999999985
# 97.5% quantile:  130000.0
# 99% quantile:    154992.80000000002
# 99.9% quantile:  212671.85600000265

# %% [markdown]
# Since it is possible for company vehicles or vehicles used for long journeys to reach 317 thousand km, the values that appear as outliers are not considered as outliers. Therefore, no action will be taken.

# %% [markdown]
# ## Gears

# %%
df.Gears.describe()
# Out:
# count   15909.000
# mean        5.938
# std         0.705
# min         5.000
# 25%         5.000
# 50%         6.000
# 75%         6.000
# max         8.000
# Name: Gears, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.Gears)

plt.subplot(122)
plt.hist(df.Gears,bins=10);

# %%
limits(df,"Gears")
# Out:
# Lower Limit: 3.5
# Upper limit: 7.5

# %%
outliers(df,"Gears")
# Out:
# 225

# %% [markdown]
# Values above the upper limit are not considered outliers, as it may be a vehicle with 8 gears.

# %% [markdown]
# ## Previous_Owners

# %%
df.Previous_Owners.describe()
# Out:
# count   15909.000
# mean        1.040
# std         0.254
# min         0.000
# 25%         1.000
# 50%         1.000
# 75%         1.000
# max         4.000
# Name: Previous_Owners, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.Previous_Owners)

plt.subplot(122)
plt.hist(df.Previous_Owners,bins=10);

# %%
limits(df,"Previous_Owners")
# Out:
# Lower Limit: 1.0
# Upper limit: 1.0

# %%
outliers(df,"Previous_Owners")
# Out:
# 985

# %% [markdown]
# Since vehicle owners can change vehicles frequently for different reasons, it is considered normal that one vehicle can change 4 vehicles within 3 years.

# %% [markdown]
# ## hp_kW

# %%
df.hp_kW.describe()
# Out:
# count   15909.000
# mean       88.371
# std        26.834
# min         1.000
# 25%        66.000
# 50%        85.000
# 75%       101.000
# max       294.000
# Name: hp_kW, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.hp_kW)

plt.subplot(122)
plt.hist(df.hp_kW,bins=20);

# %%
limits(df,"hp_kW")
# Out:
# Lower Limit: 13.5
# Upper limit: 153.5

# %%
outliers(df,"hp_kW")
# Out:
# 427

# %% [markdown]
# It has been evaluated that there cannot be a vehicle below 50 hp_kW and these values have been converted to Nan values.

# %%
(df.hp_kW <50).sum()
# Out:
# 25

# %%
df.hp_kW.loc[(df.hp_kW <50)] = 50

# %%
df.make_model.unique()
# Out:
# array(['Audi A1', 'Audi A3', 'Opel Astra', 'Opel Corsa', 'Opel Insignia',
#        'Renault Clio', 'Renault Duster', 'Renault Espace'], dtype=object)

# %%
(df.hp_kW >153).sum()
# Out:
# 405

# %%
winsorize_percentage_selection(df,"hp_kW")
# Out:
# 90% quantile:    122.0
# 92.5% quantile:  125.0
# 95% quantile:    146.0
# 97.5% quantile:  154.0
# 99% quantile:    165.0
# 99.9% quantile:  294.0

# %% [markdown]
# %97.5 quantile has selected.

# %%
df.hp_kW= winsorize(df["hp_kW"],(0, 0.025),inplace=True)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.hp_kW)

plt.subplot(122)
plt.hist(df.hp_kW,bins=20);

# %% [markdown]
# ## Age

# %%
df.Age.describe()
# Out:
# count   15909.000
# mean        1.390
# std         1.121
# min         0.000
# 25%         0.000
# 50%         1.000
# 75%         2.000
# max         3.000
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.Age)

plt.subplot(122)
plt.hist(df.Age,bins=20);

# %%
limits(df,"Age")
# Out:
# Lower Limit: -3.0
# Upper limit: 5.0

# %%
outliers(df,"Age")
# Out:
# 0

# %% [markdown]
# ## Nr_of_Doors

# %%
df.Nr_of_Doors.describe()
# Out:
# count   15909.000
# mean        4.655
# std         0.647
# min         1.000
# 25%         4.000
# 50%         5.000
# 75%         5.000
# max         7.000
# Name: Nr_of_Doors, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.Nr_of_Doors)

plt.subplot(122)
plt.hist(df.Nr_of_Doors,bins=20);

# %%
limits(df,"Nr_of_Doors")
# Out:
# Lower Limit: 2.5
# Upper limit: 6.5

# %%
outliers(df,"Nr_of_Doors")
# Out:
# 226

# %%
df.make_model.unique()
# Out:
# array(['Audi A1', 'Audi A3', 'Opel Astra', 'Opel Corsa', 'Opel Insignia',
#        'Renault Clio', 'Renault Duster', 'Renault Espace'], dtype=object)

# %%
(df.Nr_of_Doors >5).sum()
# Out:
# 1

# %%
(df.Nr_of_Doors < 2.5).sum()
# Out:
# 225

# %%
(df.Nr_of_Doors == 1).sum()
# Out:
# 2

# %%
(df.Nr_of_Doors == 0).sum()
# Out:
# 0

# %%
df.Nr_of_Doors.loc[(df.Nr_of_Doors == 1)] = 2

# %% [markdown]
# ['Audi A1', 'Audi A3', 'Opel Astra', 'Opel Corsa', 'Opel Insignia',
#        'Renault Clio', 'Renault Duster', 'Renault Espace'] model vehicles have been researched as having a min door number of 2 and a maximum number of doors of 5.

# %%
df= df.loc[(df.Nr_of_Doors >= 2.5) & (df.Nr_of_Doors <=5)]

# %%
df.Nr_of_Doors.describe()
# Out:
# count   15683.000
# mean        4.693
# std         0.567
# min         3.000
# 25%         4.000
# 50%         5.000
# 75%         5.000
# max         5.000
# Name: Nr_of_Doors, dtype: float64

# %%
plt.hist(df.Nr_of_Doors,bins=20);

# %% [markdown]
# ## Nr_of_Seats

# %%
df.Nr_of_Seats.describe()
# Out:
# count   15683.000
# mean        4.958
# std         0.497
# min         2.000
# 25%         5.000
# 50%         5.000
# 75%         5.000
# max         7.000
# Name: Nr_of_Seats, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.Nr_of_Seats)

plt.subplot(122)
plt.hist(df.Nr_of_Seats,bins=20);

# %%
limits(df,"Nr_of_Seats")
# Out:
# Lower Limit: 5.0
# Upper limit: 5.0

# %%
outliers(df,"Nr_of_Seats")
# Out:
# 1633

# %%
df.groupby("make_model")["body_type"].value_counts()
# Out:
# make_model      body_type
# Audi A1         Sedans           1521
#                 Compact           970
#                 Station wagon      21
#                 Coupe               1
# Audi A3         Sedans           2602
#                 Station wagon     281
#                 Compact           182
#                 Coupe               4
#                 Convertible         1
# Opel Astra      Station wagon    1285
#                 Sedans           1053
#                 Compact           185
#                 Coupe               2
#                 Off-Road            1
# Opel Corsa      Compact          1228
#                 Sedans            870
#                 Coupe              13
#                 Transporter         7
#                 Off-Road            3
# Opel Insignia   Station wagon    1662
#                 Sedans            900
#                 Compact            27
#                 Off-Road            7
# Renault Clio    Sedans            984
#                 Compact           482
#                 Station wagon     337
#                 Transporter        29
#                 Off-Road            2
#                 Coupe               1
# Renault Duster  Off-Road           34
# Renault Espace  Van               810
#                 Station wagon      91
#                 Transporter        52
#                 Sedans             21
#                 Off-Road            8
#                 Compact             6
# Name: body_type, dtype: int64

# %% [markdown]
# ['Audi A1', 'Audi A3', 'Opel Astra', 'Opel Corsa', 'Opel Insignia',
#        'Renault Clio', 'Renault Duster', 'Renault Espace'] model vehicles do not have an outlier as they have a 7-seater body_type.

# %% [markdown]
# ## Displacement_cc

# %%
df.Displacement_cc.describe()
# Out:
# count   15683.000
# mean     1427.481
# std       330.531
# min         1.000
# 25%      1229.000
# 50%      1461.000
# 75%      1598.000
# max     16000.000
# Name: Displacement_cc, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.Displacement_cc)

plt.subplot(122)
plt.hist(df.Displacement_cc,bins=20);

# %%
limits(df,"Displacement_cc")
# Out:
# Lower Limit: 675.5
# Upper limit: 2151.5

# %%
outliers(df,"Displacement_cc")
# Out:
# 74

# %%
df.make_model.unique()
# Out:
# array(['Audi A1', 'Audi A3', 'Opel Astra', 'Opel Corsa', 'Opel Insignia',
#        'Renault Clio', 'Renault Duster', 'Renault Espace'], dtype=object)

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x="make_model", y="Displacement_cc", data=df)
# Out:
# <AxesSubplot:xlabel='make_model', ylabel='Displacement_cc'>

# %%
(df.Displacement_cc > 3000).sum()
# Out:
# 2

# %%
(df.Displacement_cc <1000).sum()
# Out:
# 2911

# %%
df= df.loc[(df.Displacement_cc >= 1000) & (df.Displacement_cc <= 3000)]

# %% [markdown]
# ['Audi A1', 'Audi A3', 'Opel Astra', 'Opel Corsa', 'Opel Insignia',  'Renault Clio', 'Renault Duster', 'Renault Espace'] model vehicles have been investigated whether there is an engine below 1000 cc and no engine over 3000 cc.

# %%
df.Displacement_cc.describe()
# Out:
# count   12770.000
# mean     1529.663
# std       197.551
# min      1000.000
# 25%      1398.000
# 50%      1598.000
# 75%      1598.000
# max      2967.000
# Name: Displacement_cc, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.Displacement_cc)

plt.subplot(122)
plt.hist(df.Displacement_cc,bins=20);

# %% [markdown]
# ### Weight_kg

# %%
df.Weight_kg.describe()
# Out:
# count   12770.000
# mean     1365.030
# std       203.784
# min         1.000
# 25%      1170.000
# 50%      1360.000
# 75%      1487.000
# max      2471.000
# Name: Weight_kg, dtype: float64

# %%
limits(df, "Weight_kg")
# Out:
# Lower Limit: 694.5
# Upper limit: 1962.5

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.Weight_kg)

plt.subplot(122)
plt.hist(df.Weight_kg,bins=20);

# %%
(df.Weight_kg < 1000).sum()
# Out:
# 11

# %%
df =df.loc[(df.Weight_kg >= 1000) & (df.Weight_kg <= 3000)]

# %%
df.Weight_kg.describe()
# Out:
# count   12759.000
# mean     1365.515
# std       202.896
# min      1010.000
# 25%      1170.000
# 50%      1360.000
# 75%      1487.000
# max      2471.000
# Name: Weight_kg, dtype: float64

# %%
plt.subplot(122)
plt.hist(df.Weight_kg,bins=20);

# %% [markdown]
# ### Consumption_comb

# %%
df.Consumption_comb.describe()
# Out:
# count   12759.000
# mean        4.929
# std         1.399
# min         0.000
# 25%         4.000
# 50%         4.900
# 75%         5.544
# max        55.000
# Name: Consumption_comb, dtype: float64

# %%
limits(df,"Consumption_comb")
# Out:
# Lower Limit: 1.683610271903306
# Upper limit: 7.8606495468278235

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.Consumption_comb)

plt.subplot(122)
plt.hist(df.Consumption_comb,bins=20);

# %%
outliers(df, "Consumption_comb")
# Out:
# 90

# %%
df = df.loc[~((df.Consumption_comb < 2.27) | (df.Consumption_comb > 7.41))]

# %%
df.Consumption_comb.describe()
# Out:
# count   12648.000
# mean        4.876
# std         0.912
# min         3.000
# 25%         4.000
# 50%         4.900
# 75%         5.544
# max         7.400
# Name: Consumption_comb, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.Consumption_comb)

plt.subplot(122)
plt.hist(df.Consumption_comb,bins=20);

# %% [markdown]
# ### CO2_Emission

# %%
df.CO2_Emission.describe()
# Out:
# count   12648.000
# mean      113.166
# std        32.386
# min         1.000
# 25%       104.000
# 50%       119.000
# 75%       130.000
# max       191.000
# Name: CO2_Emission, dtype: float64

# %%
limits(df, "CO2_Emission")
# Out:
# Lower Limit: 65.0
# Upper limit: 169.0

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.CO2_Emission)

plt.subplot(122)
plt.hist(df.CO2_Emission,bins=20);

# %%
outliers(df, "CO2_Emission")
# Out:
# 912

# %%
winsorize_percentage_selection(df, "CO2_Emission")
# Out:
# 90% quantile:    141.0
# 92.5% quantile:  145.0
# 95% quantile:    149.0
# 97.5% quantile:  153.0
# 99% quantile:    168.0
# 99.9% quantile:  187.0

# %% [markdown]
# 99% quantile has selected.

# %%
df.CO2_Emission= winsorize(df["CO2_Emission"],(0, 0.01),inplace=True)

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.boxplot(df.CO2_Emission)

plt.subplot(122)
plt.hist(df.CO2_Emission,bins=20);

# %% [markdown]
# ### END OF THE PART 3

# %%
df.head(3).T
# Out:
#                                                                      0  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            15770
# vat                                                     VAT deductible
# km                                                           56013.000
# Type                                                              Used
# Fuel                                                            Diesel
# Gears                                                            7.000
# Extras                  Alloy wheels,Catalytic Converter,Voice Control
# Previous_Owners                                                  2.000
# hp_kW                                                           66.000
# Age                                                              3.000
# Paint_Type                                                    Metallic
# Upholstery_type                                                  Cloth
# Nr_of_Doors                                                      5.000
# Nr_of_Seats                                                      5.000
# Gearing_Type                                                 Automatic
# Displacement_cc                                               1422.000
# Weight_kg                                                     1220.000
# Drive_chain                                                      front
# Consumption_comb                                                 3.800
# CO2_Emission                                                    99.000
# Emission_Class                                                  Euro 6
# Comfort_Convenience  Air conditioning,Armrest,Automatic climate con...
# Entertainment_Media  Bluetooth,Hands-free equipment,On-board comput...
# Safety_Security      ABS,Central door lock,Daytime running lights,D...
#
#                                                                      1  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14500
# vat                                                   Price negotiable
# km                                                           80000.000
# Type                                                              Used
# Fuel                                                           Benzine
# Gears                                                            7.000
# Extras               Alloy wheels,Sport seats,Sport suspension,Voic...
# Previous_Owners                                                  1.000
# hp_kW                                                          141.000
# Age                                                              2.000
# Paint_Type                                                    Metallic
# Upholstery_type                                                  Cloth
# Nr_of_Doors                                                      3.000
# Nr_of_Seats                                                      4.000
# Gearing_Type                                                 Automatic
# Displacement_cc                                               1798.000
# Weight_kg                                                     1255.000
# Drive_chain                                                      front
# Consumption_comb                                                 5.600
# CO2_Emission                                                   129.000
# Emission_Class                                                  Euro 6
# Comfort_Convenience  Air conditioning,Automatic climate control,Hil...
# Entertainment_Media  Bluetooth,Hands-free equipment,On-board comput...
# Safety_Security      ABS,Central door lock,Central door lock with r...
#
#                                                                      2
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14640
# vat                                                     VAT deductible
# km                                                           83450.000
# Type                                                              Used
# Fuel                                                            Diesel
# Gears                                                            7.000
# Extras                                      Alloy wheels,Voice Control
# Previous_Owners                                                  1.000
# hp_kW                                                           85.000
# Age                                                              3.000
# Paint_Type                                                    Metallic
# Upholstery_type                                                  Cloth
# Nr_of_Doors                                                      4.000
# Nr_of_Seats                                                      4.000
# Gearing_Type                                                 Automatic
# Displacement_cc                                               1598.000
# Weight_kg                                                     1135.000
# Drive_chain                                                      front
# Consumption_comb                                                 3.800
# CO2_Emission                                                    99.000
# Emission_Class                                                  Euro 6
# Comfort_Convenience  Air conditioning,Cruise control,Electrical sid...
# Entertainment_Media                              MP3,On-board computer
# Safety_Security      ABS,Central door lock,Daytime running lights,D...

# %%
df.shape
# Out:
# (12648, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12648 entries, 0 to 15908
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           12648 non-null  object
#  1   body_type            12648 non-null  object
#  2   price                12648 non-null  int64
#  3   vat                  12648 non-null  object
#  4   km                   12648 non-null  float64
#  5   Type                 12648 non-null  object
#  6   Fuel                 12648 non-null  object
#  7   Gears                12648 non-null  float64
#  8   Extras               12648 non-null  object
#  9   Previous_Owners      12648 non-null  float64
#  10  hp_kW                12648 non-null  float64
#  11  Age                  12648 non-null  float64
#  12  Paint_Type           12648 non-null  object
#  13  Upholstery_type      12648 non-null  object
#  14  Nr_of_Doors          12648 non-null  float64
#  15  Nr_of_Seats          12648 non-null  float64
#  16  Gearing_Type         12648 non-null  object
#  17  Displacement_cc      12648 non-null  float64
#  18  Weight_kg            12648 non-null  float64
#  19  Drive_chain          12648 non-null  object
#  20  Consumption_comb     12648 non-null  float64
#  21  CO2_Emission         12648 non-null  float64
#  22  Emission_Class       12648 non-null  object
#  23  Comfort_Convenience  12648 non-null  object
#  24  Entertainment_Media  12648 non-null  object
#  25  Safety_Security      12648 non-null  object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 2.6+ MB

# %%
df.isnull().sum()
# Out:
# make_model             0
# body_type              0
# price                  0
# vat                    0
# km                     0
# Type                   0
# Fuel                   0
# Gears                  0
# Extras                 0
# Previous_Owners        0
# hp_kW                  0
# Age                    0
# Paint_Type             0
# Upholstery_type        0
# Nr_of_Doors            0
# Nr_of_Seats            0
# Gearing_Type           0
# Displacement_cc        0
# Weight_kg              0
# Drive_chain            0
# Consumption_comb       0
# CO2_Emission           0
# Emission_Class         0
# Comfort_Convenience    0
# Entertainment_Media    0
# Safety_Security        0
# dtype: int64

# %% [markdown]
# ### FINAL STEP

# %%
df.describe(exclude="object").T
# Out:
#                      count      mean       std      min       25%       50%  \
# price            12648.000 17687.870  7077.342   13.000 12490.000 16500.000
# km               12648.000 37020.848 38728.077    0.000  6671.750 24883.500
# Gears            12648.000     5.971     0.653    5.000     6.000     6.000
# Previous_Owners  12648.000     1.042     0.245    0.000     1.000     1.000
# hp_kW            12648.000    91.113    26.101   50.000    66.000    85.000
# Age              12648.000     1.530     1.096    0.000     1.000     1.000
# Nr_of_Doors      12648.000     4.688     0.574    3.000     4.000     5.000
# Nr_of_Seats      12648.000     4.992     0.506    2.000     5.000     5.000
# Displacement_cc  12648.000  1527.243   192.870 1000.000  1398.000  1598.000
# Weight_kg        12648.000  1365.099   202.577 1010.000  1173.000  1360.000
# Consumption_comb 12648.000     4.876     0.912    3.000     4.000     4.900
# CO2_Emission     12648.000   113.096    32.249    1.000   104.000   119.000
#
#                        75%        max
# price            21500.000  36498.000
# km               55000.000 317000.000
# Gears                6.000      8.000
# Previous_Owners      1.000      4.000
# hp_kW              110.000    154.000
# Age                  3.000      3.000
# Nr_of_Doors          5.000      5.000
# Nr_of_Seats          5.000      7.000
# Displacement_cc   1598.000   2000.000
# Weight_kg         1487.000   2471.000
# Consumption_comb     5.544      7.400
# CO2_Emission       130.000    168.000

# %%
numeric_columns = "price,km,Gears,Previous_Owners,hp_kW,Age,Nr_of_Doors,Nr_of_Seats,Displacement_cc,Weight_kg,Consumption_comb,CO2_Emission".split(",")

# %%
df_numeric= df[numeric_columns]

# %%
df_numeric.head(3).T
# Out:
#                          0         1         2
# price            15770.000 14500.000 14640.000
# km               56013.000 80000.000 83450.000
# Gears                7.000     7.000     7.000
# Previous_Owners      2.000     1.000     1.000
# hp_kW               66.000   141.000    85.000
# Age                  3.000     2.000     3.000
# Nr_of_Doors          5.000     3.000     4.000
# Nr_of_Seats          5.000     4.000     4.000
# Displacement_cc   1422.000  1798.000  1598.000
# Weight_kg         1220.000  1255.000  1135.000
# Consumption_comb     3.800     5.600     3.800
# CO2_Emission        99.000   129.000    99.000

# %%
plt.figure(figsize = (14,10))
sns.heatmap(df_numeric.corr(), annot = True, cmap="viridis", linewidths=0.2, annot_kws = {"size": 16});

# %%
sns.pairplot(df_numeric, size=2);

# %%
df.to_csv("auto_scout_final_without_dummies.csv")

# %% [markdown]
# ### DUMMY OPERATIONS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12648 entries, 0 to 15908
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           12648 non-null  object
#  1   body_type            12648 non-null  object
#  2   price                12648 non-null  int64
#  3   vat                  12648 non-null  object
#  4   km                   12648 non-null  float64
#  5   Type                 12648 non-null  object
#  6   Fuel                 12648 non-null  object
#  7   Gears                12648 non-null  float64
#  8   Extras               12648 non-null  object
#  9   Previous_Owners      12648 non-null  float64
#  10  hp_kW                12648 non-null  float64
#  11  Age                  12648 non-null  float64
#  12  Paint_Type           12648 non-null  object
#  13  Upholstery_type      12648 non-null  object
#  14  Nr_of_Doors          12648 non-null  float64
#  15  Nr_of_Seats          12648 non-null  float64
#  16  Gearing_Type         12648 non-null  object
#  17  Displacement_cc      12648 non-null  float64
#  18  Weight_kg            12648 non-null  float64
#  19  Drive_chain          12648 non-null  object
#  20  Consumption_comb     12648 non-null  float64
#  21  CO2_Emission         12648 non-null  float64
#  22  Emission_Class       12648 non-null  object
#  23  Comfort_Convenience  12648 non-null  object
#  24  Entertainment_Media  12648 non-null  object
#  25  Safety_Security      12648 non-null  object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 3.2+ MB

# %%
df.shape
# Out:
# (12648, 26)

# %%
df = df.join(df["Comfort_Convenience"].str.get_dummies(sep = ",").add_prefix("cc_"))
df = df.join(df["Entertainment_Media"].str.get_dummies(sep = ",").add_prefix("em_"))
df = df.join(df["Extras"].str.get_dummies(sep = ",").add_prefix("ex_"))
df = df.join(df["Safety_Security"].str.get_dummies(sep = ",").add_prefix("ss_"))

# %%
df.drop(["Comfort_Convenience","Entertainment_Media","Extras","Safety_Security"], axis=1, inplace=True)

# %%
df.head(3).T
# Out:
#                                                        0                 1  \
# make_model                                       Audi A1           Audi A1
# body_type                                         Sedans            Sedans
# price                                              15770             14500
# vat                                       VAT deductible  Price negotiable
# km                                             56013.000         80000.000
# Type                                                Used              Used
# Fuel                                              Diesel           Benzine
# Gears                                              7.000             7.000
# Previous_Owners                                    2.000             1.000
# hp_kW                                             66.000           141.000
# Age                                                3.000             2.000
# Paint_Type                                      Metallic          Metallic
# Upholstery_type                                    Cloth             Cloth
# Nr_of_Doors                                        5.000             3.000
# Nr_of_Seats                                        5.000             4.000
# Gearing_Type                                   Automatic         Automatic
# Displacement_cc                                 1422.000          1798.000
# Weight_kg                                       1220.000          1255.000
# Drive_chain                                        front             front
# Consumption_comb                                   3.800             5.600
# CO2_Emission                                      99.000           129.000
# Emission_Class                                    Euro 6            Euro 6
# cc_Air conditioning                                    1                 1
# cc_Air suspension                                      0                 0
# cc_Armrest                                             1                 0
# cc_Automatic climate control                           1                 1
# cc_Auxiliary heating                                   0                 0
# cc_Cruise control                                      1                 0
# cc_Electric Starter                                    0                 0
# cc_Electric tailgate                                   0                 0
# cc_Electrical side mirrors                             1                 0
# cc_Electrically adjustable seats                       0                 0
# cc_Electrically heated windshield                      0                 0
# cc_Heads-up display                                    0                 0
# cc_Heated steering wheel                               0                 0
# cc_Hill Holder                                         1                 1
# cc_Keyless central door lock                           0                 0
# cc_Leather seats                                       0                 0
# cc_Leather steering wheel                              1                 1
# cc_Light sensor                                        1                 0
# cc_Lumbar support                                      0                 1
# cc_Massage seats                                       0                 0
# cc_Multi-function steering wheel                       1                 0
# cc_Navigation system                                   1                 0
# cc_Panorama roof                                       0                 0
# cc_Park Distance Control                               1                 0
# cc_Parking assist system camera                        0                 0
# cc_Parking assist system self-steering                 0                 0
# cc_Parking assist system sensors front                 0                 0
# cc_Parking assist system sensors rear                  1                 1
# cc_Power windows                                       1                 1
# cc_Rain sensor                                         1                 0
# cc_Seat heating                                        1                 0
# cc_Seat ventilation                                    0                 0
# cc_Split rear seats                                    0                 0
# cc_Start-stop system                                   1                 1
# cc_Sunroof                                             0                 0
# cc_Tinted windows                                      0                 1
# cc_Wind deflector                                      0                 0
# cc_Windshield                                          0                 0
# em_Bluetooth                                           1                 1
# em_CD player                                           0                 0
# em_Digital radio                                       0                 0
# em_Hands-free equipment                                1                 1
# em_MP3                                                 0                 0
# em_On-board computer                                   1                 1
# em_Radio                                               1                 1
# em_Sound system                                        0                 1
# em_Television                                          0                 0
# em_USB                                                 0                 0
# ex_Alloy wheels                                        1                 1
# ex_Cab or rented Car                                   0                 0
# ex_Catalytic Converter                                 1                 0
# ex_Handicapped enabled                                 0                 0
# ex_Right hand drive                                    0                 0
# ex_Roof rack                                           0                 0
# ex_Shift paddles                                       0                 0
# ex_Ski bag                                             0                 0
# ex_Sliding door                                        0                 0
# ex_Sport package                                       0                 0
# ex_Sport seats                                         0                 1
# ex_Sport suspension                                    0                 1
# ex_Touch screen                                        0                 0
# ex_Trailer hitch                                       0                 0
# ex_Tuned car                                           0                 0
# ex_Voice Control                                       1                 1
# ex_Winter tyres                                        0                 0
# ss_ABS                                                 1                 1
# ss_Adaptive Cruise Control                             0                 0
# ss_Adaptive headlights                                 0                 0
# ss_Alarm system                                        0                 0
# ss_Blind spot monitor                                  0                 0
# ss_Central door lock                                   1                 1
# ss_Central door lock with remote control               0                 1
# ss_Daytime running lights                              1                 1
# ss_Driver drowsiness detection                         0                 0
# ss_Driver-side airbag                                  1                 1
# ss_Electronic stability control                        1                 1
# ss_Emergency brake assistant                           0                 0
# ss_Emergency system                                    0                 0
# ss_Fog lights                                          1                 0
# ss_Head airbag                                         0                 1
# ss_Immobilizer                                         1                 1
# ss_Isofix                                              1                 1
# ss_LED Daytime Running Lights                          0                 0
# ss_LED Headlights                                      0                 0
# ss_Lane departure warning system                       0                 0
# ss_Night view assist                                   0                 0
# ss_Passenger-side airbag                               1                 1
# ss_Power steering                                      1                 1
# ss_Rear airbag                                         0                 0
# ss_Side airbag                                         1                 1
# ss_Tire pressure monitoring system                     1                 1
# ss_Traction control                                    1                 1
# ss_Traffic sign recognition                            0                 0
# ss_Xenon headlights                                    1                 1
#
#                                                        2
# make_model                                       Audi A1
# body_type                                         Sedans
# price                                              14640
# vat                                       VAT deductible
# km                                             83450.000
# Type                                                Used
# Fuel                                              Diesel
# Gears                                              7.000
# Previous_Owners                                    1.000
# hp_kW                                             85.000
# Age                                                3.000
# Paint_Type                                      Metallic
# Upholstery_type                                    Cloth
# Nr_of_Doors                                        4.000
# Nr_of_Seats                                        4.000
# Gearing_Type                                   Automatic
# Displacement_cc                                 1598.000
# Weight_kg                                       1135.000
# Drive_chain                                        front
# Consumption_comb                                   3.800
# CO2_Emission                                      99.000
# Emission_Class                                    Euro 6
# cc_Air conditioning                                    1
# cc_Air suspension                                      0
# cc_Armrest                                             0
# cc_Automatic climate control                           0
# cc_Auxiliary heating                                   0
# cc_Cruise control                                      1
# cc_Electric Starter                                    0
# cc_Electric tailgate                                   0
# cc_Electrical side mirrors                             1
# cc_Electrically adjustable seats                       0
# cc_Electrically heated windshield                      0
# cc_Heads-up display                                    0
# cc_Heated steering wheel                               0
# cc_Hill Holder                                         1
# cc_Keyless central door lock                           0
# cc_Leather seats                                       0
# cc_Leather steering wheel                              1
# cc_Light sensor                                        0
# cc_Lumbar support                                      0
# cc_Massage seats                                       0
# cc_Multi-function steering wheel                       1
# cc_Navigation system                                   1
# cc_Panorama roof                                       0
# cc_Park Distance Control                               1
# cc_Parking assist system camera                        0
# cc_Parking assist system self-steering                 0
# cc_Parking assist system sensors front                 1
# cc_Parking assist system sensors rear                  1
# cc_Power windows                                       1
# cc_Rain sensor                                         0
# cc_Seat heating                                        1
# cc_Seat ventilation                                    0
# cc_Split rear seats                                    0
# cc_Start-stop system                                   1
# cc_Sunroof                                             0
# cc_Tinted windows                                      0
# cc_Wind deflector                                      0
# cc_Windshield                                          0
# em_Bluetooth                                           0
# em_CD player                                           0
# em_Digital radio                                       0
# em_Hands-free equipment                                0
# em_MP3                                                 1
# em_On-board computer                                   1
# em_Radio                                               0
# em_Sound system                                        0
# em_Television                                          0
# em_USB                                                 0
# ex_Alloy wheels                                        1
# ex_Cab or rented Car                                   0
# ex_Catalytic Converter                                 0
# ex_Handicapped enabled                                 0
# ex_Right hand drive                                    0
# ex_Roof rack                                           0
# ex_Shift paddles                                       0
# ex_Ski bag                                             0
# ex_Sliding door                                        0
# ex_Sport package                                       0
# ex_Sport seats                                         0
# ex_Sport suspension                                    0
# ex_Touch screen                                        0
# ex_Trailer hitch                                       0
# ex_Tuned car                                           0
# ex_Voice Control                                       1
# ex_Winter tyres                                        0
# ss_ABS                                                 1
# ss_Adaptive Cruise Control                             0
# ss_Adaptive headlights                                 0
# ss_Alarm system                                        0
# ss_Blind spot monitor                                  0
# ss_Central door lock                                   1
# ss_Central door lock with remote control               0
# ss_Daytime running lights                              1
# ss_Driver drowsiness detection                         0
# ss_Driver-side airbag                                  1
# ss_Electronic stability control                        1
# ss_Emergency brake assistant                           0
# ss_Emergency system                                    0
# ss_Fog lights                                          0
# ss_Head airbag                                         0
# ss_Immobilizer                                         1
# ss_Isofix                                              1
# ss_LED Daytime Running Lights                          0
# ss_LED Headlights                                      0
# ss_Lane departure warning system                       0
# ss_Night view assist                                   0
# ss_Passenger-side airbag                               1
# ss_Power steering                                      1
# ss_Rear airbag                                         0
# ss_Side airbag                                         1
# ss_Tire pressure monitoring system                     1
# ss_Traction control                                    1
# ss_Traffic sign recognition                            0
# ss_Xenon headlights                                    0

# %%
df_dummies= pd.get_dummies(df, drop_first=True)

# %%
df_dummies.shape
# Out:
# (12648, 137)

# %%
df_dummies.head(3).T
# Out:
#                                                  0         1         2
# price                                    15770.000 14500.000 14640.000
# km                                       56013.000 80000.000 83450.000
# Gears                                        7.000     7.000     7.000
# Previous_Owners                              2.000     1.000     1.000
# hp_kW                                       66.000   141.000    85.000
# Age                                          3.000     2.000     3.000
# Nr_of_Doors                                  5.000     3.000     4.000
# Nr_of_Seats                                  5.000     4.000     4.000
# Displacement_cc                           1422.000  1798.000  1598.000
# Weight_kg                                 1220.000  1255.000  1135.000
# Consumption_comb                             3.800     5.600     3.800
# CO2_Emission                                99.000   129.000    99.000
# cc_Air conditioning                          1.000     1.000     1.000
# cc_Air suspension                            0.000     0.000     0.000
# cc_Armrest                                   1.000     0.000     0.000
# cc_Automatic climate control                 1.000     1.000     0.000
# cc_Auxiliary heating                         0.000     0.000     0.000
# cc_Cruise control                            1.000     0.000     1.000
# cc_Electric Starter                          0.000     0.000     0.000
# cc_Electric tailgate                         0.000     0.000     0.000
# cc_Electrical side mirrors                   1.000     0.000     1.000
# cc_Electrically adjustable seats             0.000     0.000     0.000
# cc_Electrically heated windshield            0.000     0.000     0.000
# cc_Heads-up display                          0.000     0.000     0.000
# cc_Heated steering wheel                     0.000     0.000     0.000
# cc_Hill Holder                               1.000     1.000     1.000
# cc_Keyless central door lock                 0.000     0.000     0.000
# cc_Leather seats                             0.000     0.000     0.000
# cc_Leather steering wheel                    1.000     1.000     1.000
# cc_Light sensor                              1.000     0.000     0.000
# cc_Lumbar support                            0.000     1.000     0.000
# cc_Massage seats                             0.000     0.000     0.000
# cc_Multi-function steering wheel             1.000     0.000     1.000
# cc_Navigation system                         1.000     0.000     1.000
# cc_Panorama roof                             0.000     0.000     0.000
# cc_Park Distance Control                     1.000     0.000     1.000
# cc_Parking assist system camera              0.000     0.000     0.000
# cc_Parking assist system self-steering       0.000     0.000     0.000
# cc_Parking assist system sensors front       0.000     0.000     1.000
# cc_Parking assist system sensors rear        1.000     1.000     1.000
# cc_Power windows                             1.000     1.000     1.000
# cc_Rain sensor                               1.000     0.000     0.000
# cc_Seat heating                              1.000     0.000     1.000
# cc_Seat ventilation                          0.000     0.000     0.000
# cc_Split rear seats                          0.000     0.000     0.000
# cc_Start-stop system                         1.000     1.000     1.000
# cc_Sunroof                                   0.000     0.000     0.000
# cc_Tinted windows                            0.000     1.000     0.000
# cc_Wind deflector                            0.000     0.000     0.000
# cc_Windshield                                0.000     0.000     0.000
# em_Bluetooth                                 1.000     1.000     0.000
# em_CD player                                 0.000     0.000     0.000
# em_Digital radio                             0.000     0.000     0.000
# em_Hands-free equipment                      1.000     1.000     0.000
# em_MP3                                       0.000     0.000     1.000
# em_On-board computer                         1.000     1.000     1.000
# em_Radio                                     1.000     1.000     0.000
# em_Sound system                              0.000     1.000     0.000
# em_Television                                0.000     0.000     0.000
# em_USB                                       0.000     0.000     0.000
# ex_Alloy wheels                              1.000     1.000     1.000
# ex_Cab or rented Car                         0.000     0.000     0.000
# ex_Catalytic Converter                       1.000     0.000     0.000
# ex_Handicapped enabled                       0.000     0.000     0.000
# ex_Right hand drive                          0.000     0.000     0.000
# ex_Roof rack                                 0.000     0.000     0.000
# ex_Shift paddles                             0.000     0.000     0.000
# ex_Ski bag                                   0.000     0.000     0.000
# ex_Sliding door                              0.000     0.000     0.000
# ex_Sport package                             0.000     0.000     0.000
# ex_Sport seats                               0.000     1.000     0.000
# ex_Sport suspension                          0.000     1.000     0.000
# ex_Touch screen                              0.000     0.000     0.000
# ex_Trailer hitch                             0.000     0.000     0.000
# ex_Tuned car                                 0.000     0.000     0.000
# ex_Voice Control                             1.000     1.000     1.000
# ex_Winter tyres                              0.000     0.000     0.000
# ss_ABS                                       1.000     1.000     1.000
# ss_Adaptive Cruise Control                   0.000     0.000     0.000
# ss_Adaptive headlights                       0.000     0.000     0.000
# ss_Alarm system                              0.000     0.000     0.000
# ss_Blind spot monitor                        0.000     0.000     0.000
# ss_Central door lock                         1.000     1.000     1.000
# ss_Central door lock with remote control     0.000     1.000     0.000
# ss_Daytime running lights                    1.000     1.000     1.000
# ss_Driver drowsiness detection               0.000     0.000     0.000
# ss_Driver-side airbag                        1.000     1.000     1.000
# ss_Electronic stability control              1.000     1.000     1.000
# ss_Emergency brake assistant                 0.000     0.000     0.000
# ss_Emergency system                          0.000     0.000     0.000
# ss_Fog lights                                1.000     0.000     0.000
# ss_Head airbag                               0.000     1.000     0.000
# ss_Immobilizer                               1.000     1.000     1.000
# ss_Isofix                                    1.000     1.000     1.000
# ss_LED Daytime Running Lights                0.000     0.000     0.000
# ss_LED Headlights                            0.000     0.000     0.000
# ss_Lane departure warning system             0.000     0.000     0.000
# ss_Night view assist                         0.000     0.000     0.000
# ss_Passenger-side airbag                     1.000     1.000     1.000
# ss_Power steering                            1.000     1.000     1.000
# ss_Rear airbag                               0.000     0.000     0.000
# ss_Side airbag                               1.000     1.000     1.000
# ss_Tire pressure monitoring system           1.000     1.000     1.000
# ss_Traction control                          1.000     1.000     1.000
# ss_Traffic sign recognition                  0.000     0.000     0.000
# ss_Xenon headlights                          1.000     1.000     0.000
# make_model_Audi A3                           0.000     0.000     0.000
# make_model_Opel Astra                        0.000     0.000     0.000
# make_model_Opel Corsa                        0.000     0.000     0.000
# make_model_Opel Insignia                     0.000     0.000     0.000
# make_model_Renault Clio                      0.000     0.000     0.000
# make_model_Renault Espace                    0.000     0.000     0.000
# body_type_Convertible                        0.000     0.000     0.000
# body_type_Coupe                              0.000     0.000     0.000
# body_type_Off-Road                           0.000     0.000     0.000
# body_type_Sedans                             1.000     1.000     1.000
# body_type_Station wagon                      0.000     0.000     0.000
# body_type_Transporter                        0.000     0.000     0.000
# body_type_Van                                0.000     0.000     0.000
# vat_VAT deductible                           1.000     0.000     1.000
# Type_Employee's car                          0.000     0.000     0.000
# Type_New                                     0.000     0.000     0.000
# Type_Pre-registered                          0.000     0.000     0.000
# Type_Used                                    1.000     1.000     1.000
# Fuel_Diesel                                  1.000     0.000     1.000
# Fuel_Electric                                0.000     0.000     0.000
# Fuel_LPG                                     0.000     0.000     0.000
# Fuel_Super 95                                0.000     0.000     0.000
# Paint_Type_Perl effect                       0.000     0.000     0.000
# Paint_Type_Uni/basic                         0.000     0.000     0.000
# Upholstery_type_Leather                      0.000     0.000     0.000
# Gearing_Type_Manual                          0.000     0.000     0.000
# Gearing_Type_Semi-automatic                  0.000     0.000     0.000
# Drive_chain_front                            1.000     1.000     1.000
# Drive_chain_rear                             0.000     0.000     0.000
# Emission_Class_Euro 5                        0.000     0.000     0.000
# Emission_Class_Euro 6                        1.000     1.000     1.000

# %%
df.to_csv("auto_scout_final_with_dummies.csv")
